# %%
import awswrangler as wr

import mlflow

# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# %env AWS_ENDPOINT_URL_S3=http://localhost:9000
#%env MLFLOW_S3_ENDPOINT_URL=http://192.168.0.21:9000
#%env AWS_ENDPOINT_URL_S3=http://192.168.0.21:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# env: AWS_ENDPOINT_URL_S3=http://localhost:9000

# %% [markdown]
# # Búsqueda de mejor modelo e hiperparámetros
#
# Dado nuestro dataset de Heart Disease, el cual ya pasó por el proceso de ETL y se encuentra en nuestro S3 bucket, vamos a realizar una búsqueda de cual seria el mejor modelo y que hiperparametros usar.
#
# La búsqueda de hiperparametros la haremos usando Optuna y el tracking será realizado mediante MLFlow.
#
# OBS: Para la confección de esta notebook, nos basamos en el tutorial de [MLFlow](https://mlflow.org/docs/latest/traditional-ml/hyperparameter-tuning-with-child-runs/notebooks/index.html).

# %%
mlflow_server = "http://localhost:5001"
#mlflow_server = "http://192.168.0.21:5001"

mlflow.set_tracking_uri(mlflow_server)

# %%
# Cargamos los datos para realizar nuestro estudio.
# OBS, no vamos a cargar los datos de testing, nada de Data leakage por aquí
X_train =  wr.s3.read_csv("s3://data/final/train/heart_X_train.csv")
y_train =  wr.s3.read_csv("s3://data/final/train/heart_y_train.csv")

X_test =  wr.s3.read_csv("s3://data/final/test/heart_X_test.csv")
y_test =  wr.s3.read_csv("s3://data/final/test/heart_y_test.csv")

# %% [markdown]
# ## Investigamos la correlación de features con la variable objetivo
#
# Antes de profundizar en el proceso de construcción de modelo, es esencial comprender las relaciones entre nuestras features  y la variable objetivo. Por lo que vamos a realizar un gráfico que indica el coeficiente de correlación de cada feature en relación con la variable objetivo. Esto nos sirve para:
#
# - Evitar data leakage: Debemos asegurarnos de que ninguna característica se correlacione perfectamente con el objetivo (un coeficiente de correlación de aproximadamente 1.0). Si existe tal correlación, es una señal de que nuestro conjunto de datos podría estar "filtrando" información sobre el objetivo.
#
# - Garantizar relaciones significativas: Idealmente, nuestras características deberían tener algún grado de correlación con el objetivo. Inclusive si estamos trabajando con un problema de clasificación, aunque los resultados no son tan importantes como en un caso de regresión.
#
# - Auditoría y trazabilidad: Loggear esta visualización de correlación con nuestra ejecución principal de MLflow garantiza la trazabilidad. Proporciona una instantánea de las características de los datos en el momento del entrenamiento del modelo, lo cual es invaluable para propósitos de auditoría y replicabilidad.

# %%
from plots import plot_correlation_with_target, plot_information_gain_with_target

# %%
# Dado que estamos usando como tracking a MLFlow, mostrar los gráficos aquí no tiene sentido.
correlation_plot = plot_correlation_with_target(X_train, y_train)
information_gain_plot = plot_information_gain_with_target(X_train, y_train)

# %% [markdown]
# ## Arrancamos a experimentar

# %%
import datetime
import optuna

from mlflow.models import infer_signature
from mlflow_aux import get_or_create_experiment

from optuna_aux import champion_callback, objective

from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# Optuna es un poco verboso, dejamos que solo nos muestre logs de errores
optuna.logging.set_verbosity(optuna.logging.ERROR)

# %% [markdown]
# Antes de poder realizar experimentos, vamos a crear el experimento en MLFLow, pero para evitar desorden, vamos a usar una función que se fije primero si el experimento existe, si esto es así, devuelve su ID.
#
# Además creamos el nombre del run padre con el que vamos a ir registrando las ejecuciones.

# %%
# Creemos el experimento
experiment_id = get_or_create_experiment("Heart Disease")
print(experiment_id)

run_name_parent = "best_hyperparam_"  + datetime.datetime.today().strftime('%Y/%m/%d-%H:%M:%S"')
# Out:
# 1

# %% [markdown]
# Ya con todo seteado, vamos a ejecutar la optimización usando Optuna, el cual realiza una búsqueda Bayesiana, la cual es más eficiente que una búsqueda de grilla tradicional. La desventaja es que es más difícil de paralelizar.

# %%
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name_parent, nested=True):
    # Inicializamos el estudio de Optuna
    study = optuna.create_study(direction="maximize")

    # Ejecutamos los trials de optimización de hiperparametros. Cada uno de estos trials se ejecuta con un run separado, pero 
    # está anidado al run padre.
    # Notar la adición del `champion_callback` para controlar qué mensajes mostramos
    # Para entender mejor esto ver la documentación de objective y champion_callback en optuna_aux
    study.optimize(lambda trial: objective(trial, X_train, y_train, experiment_id), n_trials=250, callbacks=[champion_callback])

    # Una vez que terminamos la búsqueda, guardamos los mejores parámetros en el run padre.
    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_train_f1", study.best_value)

    mlflow.set_tags(
        tags={
            "project": "Heart Disease",
            "optimizer_engine": "optuna",
            "model_family": "sklearn",
            "feature_set_version": 1,
        }
    )

    # Una vez que terminamos la búsqueda, nos quedamos con el mejor modelo y lo entrenamos
    if study.best_params["classifier"] == "SVC_linear":
        model = SVC(C=study.best_params["svc_c"], kernel='linear', gamma='scale')
    elif study.best_params["classifier"] == "SVC_poly":
        model = SVC(C=study.best_params["svc_c"], kernel='poly', 
                    gamma='scale', degree=study.best_params["svc_poly_degree"])
    elif study.best_params["classifier"] == "SVC_rbf":
        model = SVC(C=study.best_params["svc_c"], kernel='rbf', gamma='scale')
    elif study.best_params["classifier"] == "DecisionTreeClassifier":
        model = DecisionTreeClassifier(max_depth=study.best_params["tree_max_depth"])
    else:
        model = RandomForestClassifier(max_depth=study.best_params["rf_max_depth"], 
                                       n_estimators=study.best_params["rf_n_estimators"])

    model = model.fit(X_train, y_train.to_numpy().ravel())

    # Y testeamos el modelo y logueamos el resultado
    y_pred = model.predict(X_test)
    f1_score = f1_score(y_test.to_numpy().ravel(), y_pred)
    mlflow.log_metric("test_f1", f1_score)

    # Logueamos los artefactos de las gráficas de correlación y de information_gain
    mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")
    mlflow.log_figure(figure=information_gain_plot, artifact_file="information_gain_plot.png")

    # Guardamos el artefacto del modelo
    artifact_path = "model"

    signature = infer_signature(X_train, model.predict(X_train))

    mlflow.sklearn.log_model(
        sk_model=model,
        artifact_path=artifact_path,
        signature=signature,
        serialization_format='cloudpickle',
        registered_model_name="heart_disease_model_dev",
        metadata={"model_data_version": 1}
    )

    # Obtenemos la ubicación del modelo guardado en MLFlow
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# 🏃 View run Trial: 0 at: http://localhost:5001/#/experiments/1/runs/67b9c0c3ad1f4edfb5017c2032d8f2ac
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Initial trial 0 achieved value: 0.7783783783783784
# 🏃 View run Trial: 1 at: http://localhost:5001/#/experiments/1/runs/8321ab668fdd457eb03d968aeffc0b93
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 2 at: http://localhost:5001/#/experiments/1/runs/b597432a249e4db3b03a235890bcaf44
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 2 achieved value: 0.7863063063063064 with  1.0082% improvement
# 🏃 View run Trial: 3 at: http://localhost:5001/#/experiments/1/runs/9ba3beb384a64af4b7a4581882b76f7b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 4 at: http://localhost:5001/#/experiments/1/runs/ded122f2c06346e09dab4490e4828909
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 5 at: http://localhost:5001/#/experiments/1/runs/de8f819fa1294e52aa383f5622368e09
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 6 at: http://localhost:5001/#/experiments/1/runs/25e39cb0f05f439aba38541af56e8f00
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 7 at: http://localhost:5001/#/experiments/1/runs/66c78a3bae004bf4842de32ec9aab348
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 8 at: http://localhost:5001/#/experiments/1/runs/3c7bfa5645924afb97087656f99e571a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 9 at: http://localhost:5001/#/experiments/1/runs/bcb6948b7ddd4f0785fd0c825746be10
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 9 achieved value: 0.79014652014652 with  0.4860% improvement
# 🏃 View run Trial: 10 at: http://localhost:5001/#/experiments/1/runs/09046d2291f04d7c83d65a2397e12ccc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 11 at: http://localhost:5001/#/experiments/1/runs/f468d8059bb74a64a96277b4b28f73de
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 12 at: http://localhost:5001/#/experiments/1/runs/950a9b8ad200477d8aad64fd5a4dfc0f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 13 at: http://localhost:5001/#/experiments/1/runs/b01a10b106ca4715b973caae3900c4ba
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 14 at: http://localhost:5001/#/experiments/1/runs/6e35463b95ef45c5be445c89fcb720e4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 15 at: http://localhost:5001/#/experiments/1/runs/b6d703783a0a4d959c6592af1b6b2ef7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 16 at: http://localhost:5001/#/experiments/1/runs/e77f8379ae114caea308453fe40881c9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 17 at: http://localhost:5001/#/experiments/1/runs/4978a644a0b54ce788c3cd7ee789625e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 18 at: http://localhost:5001/#/experiments/1/runs/b0753b5b90fe49fc8ddc78aff12f7a79
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 19 at: http://localhost:5001/#/experiments/1/runs/26a362f6650a4c67ac88e351faf66281
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 20 at: http://localhost:5001/#/experiments/1/runs/eb2394891b5848218ff9ef05b096a701
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 21 at: http://localhost:5001/#/experiments/1/runs/399d6dc6bb874f6bb4d6f63ea2cad08e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 22 at: http://localhost:5001/#/experiments/1/runs/1d2ea9f8e4114266a3952f7bb7450ee4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 23 at: http://localhost:5001/#/experiments/1/runs/b9f9bc82c4ed41b3ae21513835527bdd
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 24 at: http://localhost:5001/#/experiments/1/runs/a6cb34ed963943c8973228abe70e18c4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 25 at: http://localhost:5001/#/experiments/1/runs/e43c1d767f1a4aa5b535ab6bdb8844e1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 26 at: http://localhost:5001/#/experiments/1/runs/46634b9696ea4a20a126716a0c1b362c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 27 at: http://localhost:5001/#/experiments/1/runs/b17d2a4a62bb4174b625eda934942b86
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 28 at: http://localhost:5001/#/experiments/1/runs/cef59e61a7dd42f0bf95cddc51bdfd4d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 29 at: http://localhost:5001/#/experiments/1/runs/de6c810e25c14e15a245bb623ad50b1b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 29 achieved value: 0.8081268765234494 with  2.2249% improvement
# 🏃 View run Trial: 30 at: http://localhost:5001/#/experiments/1/runs/bf64ae7f0c064d5aa6d5aa9b1b3ae6f6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 30 achieved value: 0.8204384497067425 with  1.5006% improvement
# 🏃 View run Trial: 31 at: http://localhost:5001/#/experiments/1/runs/f3b369cb9c2947199c60163d9d55ce80
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 32 at: http://localhost:5001/#/experiments/1/runs/30e1045c963149759886eb9a3716357d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 33 at: http://localhost:5001/#/experiments/1/runs/8e0d87159ad347b7910d61875d309ca4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 34 at: http://localhost:5001/#/experiments/1/runs/b3c935313217466cb7d7c24a4e0d7bb3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 35 at: http://localhost:5001/#/experiments/1/runs/3f75c9f09c6c4119af392b14b897b2ce
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 36 at: http://localhost:5001/#/experiments/1/runs/93a757ac4c8e480fb68cccf96d8d931f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 37 at: http://localhost:5001/#/experiments/1/runs/4d6b10ed25b34b24a7c4f05ed36491db
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 38 at: http://localhost:5001/#/experiments/1/runs/cebe29a8449b4bc1916a5dbeafe65b96
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 39 at: http://localhost:5001/#/experiments/1/runs/1b782314ad8943dc811706f22b1b78a7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 40 at: http://localhost:5001/#/experiments/1/runs/219d3632f38c4bc09a51bcf444945c53
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 41 at: http://localhost:5001/#/experiments/1/runs/d028f32ed0794f2f9cfec096a3c19be2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 42 at: http://localhost:5001/#/experiments/1/runs/49d439d6ad09487f8f28ead7714903fc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 43 at: http://localhost:5001/#/experiments/1/runs/4b14c2c41b6e4f3392adc40709add1bf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 44 at: http://localhost:5001/#/experiments/1/runs/b6a6f0319aa342f882e1c97931192f19
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 45 at: http://localhost:5001/#/experiments/1/runs/84bf8818d1c144329c7b71b6036ff8f0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 46 at: http://localhost:5001/#/experiments/1/runs/1c44a9664ea34e5b9d5cfa4590af18ea
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 47 at: http://localhost:5001/#/experiments/1/runs/6941781403384df0991d66953d8cc4f4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 48 at: http://localhost:5001/#/experiments/1/runs/94ab8dd8642a4d659f8818738fba8fc6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 49 at: http://localhost:5001/#/experiments/1/runs/50adeb251d0d4668a391f877d0c99648
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 50 at: http://localhost:5001/#/experiments/1/runs/21e0d5865a514979b8f3925c0cbb8d84
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 51 at: http://localhost:5001/#/experiments/1/runs/052d3ddf7ced4710b6beff2b45c1d852
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 52 at: http://localhost:5001/#/experiments/1/runs/3eaa1cc3e35d41959d5c17204cff0d25
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 53 at: http://localhost:5001/#/experiments/1/runs/dded656779dd4d34954d1432bc186e1f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 54 at: http://localhost:5001/#/experiments/1/runs/f74fd92695224889b0de781222f770a1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 55 at: http://localhost:5001/#/experiments/1/runs/5becff6f77b34fd1ac1c7fbc6772dbab
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 56 at: http://localhost:5001/#/experiments/1/runs/62d4fd8dde9c46b0ad50edc706463253
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 57 at: http://localhost:5001/#/experiments/1/runs/aa615b93539e47408ef8ea111f040eaf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 58 at: http://localhost:5001/#/experiments/1/runs/339a7bc3372b4dcab5622ed352cb062b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 59 at: http://localhost:5001/#/experiments/1/runs/2e456523dc284cd39acec259a9bc268c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 60 at: http://localhost:5001/#/experiments/1/runs/82514f1b705c4419ab37bf0a4950fae2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 61 at: http://localhost:5001/#/experiments/1/runs/6a8980176c9d404ea220948f9876c117
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 62 at: http://localhost:5001/#/experiments/1/runs/6ab1bfda87c34c2e83836dc73230bc2d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 63 at: http://localhost:5001/#/experiments/1/runs/66b14d4e4c094bba8aacc86d0d4c2026
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 64 at: http://localhost:5001/#/experiments/1/runs/26d74f9cd49d4419b5be394869150da4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 65 at: http://localhost:5001/#/experiments/1/runs/afadb595fa25451f883ddd8f06257778
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 66 at: http://localhost:5001/#/experiments/1/runs/db6f424d2551401096a4f43501149e04
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 67 at: http://localhost:5001/#/experiments/1/runs/34f47463c64a409ba0ed9810cbafa049
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 68 at: http://localhost:5001/#/experiments/1/runs/3b27b6fa60dd4766a0ddfc06f94a46a9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 69 at: http://localhost:5001/#/experiments/1/runs/6f3ea59692d3424a85cdf3bff4bd8437
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 70 at: http://localhost:5001/#/experiments/1/runs/0546dd4d2eee4763ab6391ec1c19b63a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 71 at: http://localhost:5001/#/experiments/1/runs/1945ca44326f4718addbb2189cac2071
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 72 at: http://localhost:5001/#/experiments/1/runs/9d6944e7e1a24c39a0e44f200654d6c1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 73 at: http://localhost:5001/#/experiments/1/runs/d2ac1712495541c3b64810d57c9421c6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 74 at: http://localhost:5001/#/experiments/1/runs/d1e667d391f149f78ff7b78fd04f4e75
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 75 at: http://localhost:5001/#/experiments/1/runs/9f8e18c0be5d4c1f8098a7d3baefddc3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 76 at: http://localhost:5001/#/experiments/1/runs/6b8486ca52bb4cf09a23c4e01a39e153
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 77 at: http://localhost:5001/#/experiments/1/runs/da1a6462232e43e685d9c4668bf6badc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 78 at: http://localhost:5001/#/experiments/1/runs/69855629664d428b96215c0d6924a17c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 79 at: http://localhost:5001/#/experiments/1/runs/84f1c4a70739461d960d597014158250
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 80 at: http://localhost:5001/#/experiments/1/runs/30f58a0e84914e5a94e2153d40cd16e3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 81 at: http://localhost:5001/#/experiments/1/runs/33b1d78da0544c99bef8ad15089517e3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 82 at: http://localhost:5001/#/experiments/1/runs/025d5d37c2c04f879c75740a52f2e9eb
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 83 at: http://localhost:5001/#/experiments/1/runs/d8a67ffcca06455690b47d1630a96c81
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 84 at: http://localhost:5001/#/experiments/1/runs/a3e866609d0f4a50812ea088dbb72658
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 85 at: http://localhost:5001/#/experiments/1/runs/6a40e07a54894c1e922542ccdaa49985
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 86 at: http://localhost:5001/#/experiments/1/runs/616eba8b5e73485ba85a9d41ba6879ad
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 87 at: http://localhost:5001/#/experiments/1/runs/0daa36a5f862491ebf68999360b26793
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 88 at: http://localhost:5001/#/experiments/1/runs/cc8cf8da11a6481f9a65326e9cc097f0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 89 at: http://localhost:5001/#/experiments/1/runs/097d4a86e49d4d24ba4c070273a5857a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 90 at: http://localhost:5001/#/experiments/1/runs/b3b4e3c63b5b4237809e0eb842853cde
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 91 at: http://localhost:5001/#/experiments/1/runs/875cc9ae27374058ba015e3ce0a9e8c3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 92 at: http://localhost:5001/#/experiments/1/runs/135025dca203427897636be6c198d26b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 93 at: http://localhost:5001/#/experiments/1/runs/b5afb453d978429d949af5c842b21ac3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 94 at: http://localhost:5001/#/experiments/1/runs/60d5a9983b164902bafa0515cb7a3cb3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 95 at: http://localhost:5001/#/experiments/1/runs/a5d84cc471e745e397ff9f93db67ce05
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 96 at: http://localhost:5001/#/experiments/1/runs/eede818dc3ea43db84b842d69c189e6a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 97 at: http://localhost:5001/#/experiments/1/runs/c5bb35d8b9e244e5a919269f6e5ba708
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 98 at: http://localhost:5001/#/experiments/1/runs/111dcd1dadfb4c659d0bcfa85481722c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 99 at: http://localhost:5001/#/experiments/1/runs/73d36dffc1c4464789be9dd0faf3573a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 100 at: http://localhost:5001/#/experiments/1/runs/7ed7deb34d4b451d98e3395b75f3a6bc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 101 at: http://localhost:5001/#/experiments/1/runs/02ca3d60778e480c9b384b51bef967ee
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 102 at: http://localhost:5001/#/experiments/1/runs/bfe239ba2bac498d80612df9b921f902
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 103 at: http://localhost:5001/#/experiments/1/runs/925cdabfcf54446b854b8f0c5166a110
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 104 at: http://localhost:5001/#/experiments/1/runs/dc6e898cd67a47b98fb2a8ba0c2744c1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 105 at: http://localhost:5001/#/experiments/1/runs/c9f707b18214443cba053b75a27a387c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 106 at: http://localhost:5001/#/experiments/1/runs/b69a903b7a8b49678caa7b5783268455
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 107 at: http://localhost:5001/#/experiments/1/runs/c643a90e397047c5b4d1a1e59a5be97e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 108 at: http://localhost:5001/#/experiments/1/runs/88b4c67d134f46efadd2aeb2a9e705ae
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 109 at: http://localhost:5001/#/experiments/1/runs/d4693ae0d6ee4ab4a3c0f420276c601e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 110 at: http://localhost:5001/#/experiments/1/runs/b8b239cd96f344c5b62e4c1dfd091704
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 111 at: http://localhost:5001/#/experiments/1/runs/f2a1971e3cdf43a5a670caa3adb67b18
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 112 at: http://localhost:5001/#/experiments/1/runs/62abad9c199c40c4852b48dac87e63e6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 113 at: http://localhost:5001/#/experiments/1/runs/7b680ab6c851460e99526d546f9a92e4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 114 at: http://localhost:5001/#/experiments/1/runs/559aba0f047f40a8bd76252653bd0ef6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 115 at: http://localhost:5001/#/experiments/1/runs/ce6fac5ae08748609a51928403f97c8d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 116 at: http://localhost:5001/#/experiments/1/runs/0c49d426d1e642eaab79decae4818a9c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 117 at: http://localhost:5001/#/experiments/1/runs/fc90c675f3204e0484330292ce4ec75a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 118 at: http://localhost:5001/#/experiments/1/runs/d579c342ab71448faf849ebb0fbb6e54
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 119 at: http://localhost:5001/#/experiments/1/runs/dbc36264e0f14b999019dc354972508e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 120 at: http://localhost:5001/#/experiments/1/runs/3a833cd1f9f6470b92b0a7497cc2d5e2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 121 at: http://localhost:5001/#/experiments/1/runs/b38277a0a60e497c962300bfe7e018bb
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 122 at: http://localhost:5001/#/experiments/1/runs/6ee16c5fd71e4d1da60408e2e80cf46d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 123 at: http://localhost:5001/#/experiments/1/runs/ea03e859f8c14953b4636941f809e912
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 124 at: http://localhost:5001/#/experiments/1/runs/0e7219105f47401a87e333bbfea731ea
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Trial 124 achieved value: 0.8226076626076626 with  0.2637% improvement
# 🏃 View run Trial: 125 at: http://localhost:5001/#/experiments/1/runs/9215eae34e724cadba8bf780c90dbda9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 126 at: http://localhost:5001/#/experiments/1/runs/a473d8249b1d47f082e034b5fc50eaca
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 127 at: http://localhost:5001/#/experiments/1/runs/1f54f89db0974e1f8e1fbc13e0d3a596
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 128 at: http://localhost:5001/#/experiments/1/runs/73d01fbcca55456b962b30c249906fd8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 129 at: http://localhost:5001/#/experiments/1/runs/d3d64896fd014d9e9415e737c8b29180
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 130 at: http://localhost:5001/#/experiments/1/runs/ac8b735d16ce4a72afa591fdc7c687a2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 131 at: http://localhost:5001/#/experiments/1/runs/05ef62afffa9476097b5214ce87140b5
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 132 at: http://localhost:5001/#/experiments/1/runs/cc1064714204468390d24b035fe0dee9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 133 at: http://localhost:5001/#/experiments/1/runs/bb00ac6af37042e99d72c20ef5b75990
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 134 at: http://localhost:5001/#/experiments/1/runs/9546acdd4e174999af7bd0c2ea008302
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 135 at: http://localhost:5001/#/experiments/1/runs/27584ae5fe054a21bf1439573d1d9dea
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 136 at: http://localhost:5001/#/experiments/1/runs/9e19d417ee7446febfab7ea18927cb4e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 137 at: http://localhost:5001/#/experiments/1/runs/bba890f93b714617911c4e927aae9b05
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 138 at: http://localhost:5001/#/experiments/1/runs/ddce4ccb83ec4c04a8921d50eebbb033
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 139 at: http://localhost:5001/#/experiments/1/runs/ff2a608e965a4baba108c28c125aba4d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 140 at: http://localhost:5001/#/experiments/1/runs/edcf97b68f9b4396ab31cf82b2d88d03
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 141 at: http://localhost:5001/#/experiments/1/runs/7bdda5f6fd5f48a683b14d4a3e057f3f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 142 at: http://localhost:5001/#/experiments/1/runs/5886e05b0bb1471f9269c3adfa46b3c9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 143 at: http://localhost:5001/#/experiments/1/runs/c0fed2f880ef4d98b1e5b4fb54f1a17b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 144 at: http://localhost:5001/#/experiments/1/runs/845c7f6627e6458c9ea0afb71445332b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 145 at: http://localhost:5001/#/experiments/1/runs/58706cc4514342098bece2222eef0966
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 146 at: http://localhost:5001/#/experiments/1/runs/dc12b57ac6f64f8192158beea162f6a1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 147 at: http://localhost:5001/#/experiments/1/runs/740e5cc206564a6f87fdf75c890c6bbf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 148 at: http://localhost:5001/#/experiments/1/runs/1abe8ab09d254dc1a5ed07c9258c7dc7
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 149 at: http://localhost:5001/#/experiments/1/runs/55b26e91574542a6b735abd5c890b4dc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 150 at: http://localhost:5001/#/experiments/1/runs/ae181e0cece34431832ec172e4d90f09
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 151 at: http://localhost:5001/#/experiments/1/runs/1980856d4a3c4ffbab56fbf08102d347
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 152 at: http://localhost:5001/#/experiments/1/runs/23f6b5f3cd8b43e9b73f07137ae72d0a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 153 at: http://localhost:5001/#/experiments/1/runs/d288ec9bf70043e2b947df05b417f49b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 154 at: http://localhost:5001/#/experiments/1/runs/15ee54e633d944618d59c75f1295ae96
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 155 at: http://localhost:5001/#/experiments/1/runs/c1846e6d900b45b99675ed762488e090
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 156 at: http://localhost:5001/#/experiments/1/runs/6cde6b6d14c945f68108a7528e1947ba
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 157 at: http://localhost:5001/#/experiments/1/runs/556e9765ee7949dc967ad80b7a5d3ba6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 158 at: http://localhost:5001/#/experiments/1/runs/c61e3c5442d64c9289404b9e74c6e87d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 159 at: http://localhost:5001/#/experiments/1/runs/c64db302538b40fba39a2ec6f28472f2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 160 at: http://localhost:5001/#/experiments/1/runs/ccba4da9337b4b9f83f9b58f825b13bd
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 161 at: http://localhost:5001/#/experiments/1/runs/3b5fbda68c9a443f9914ef0d69f99cda
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 162 at: http://localhost:5001/#/experiments/1/runs/7b87556f519342329fc3a601c5f5a628
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 163 at: http://localhost:5001/#/experiments/1/runs/fb238c64a10342a5beb14e3aceb3a252
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 164 at: http://localhost:5001/#/experiments/1/runs/08b4db561ee64b0abe4e69cb1dbd7eb0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 165 at: http://localhost:5001/#/experiments/1/runs/e6d89fb40a654fc0bd5493977231289d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 166 at: http://localhost:5001/#/experiments/1/runs/ae84c5f18524409aa94e69a3f0e24653
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 167 at: http://localhost:5001/#/experiments/1/runs/343cbdb1d62d40fcbb178db52b3b91a4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 168 at: http://localhost:5001/#/experiments/1/runs/d69d92decc84404e966c34dddef80914
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 169 at: http://localhost:5001/#/experiments/1/runs/57f7044a7d734421965452ca5a2cd270
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 170 at: http://localhost:5001/#/experiments/1/runs/9e84590a0ec1433ab41de9e8d1361f02
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 171 at: http://localhost:5001/#/experiments/1/runs/a8e2e32793cf4eaeabe3535fe0b18478
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 172 at: http://localhost:5001/#/experiments/1/runs/0db373def3fa4cca98f1b1600ca35979
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 173 at: http://localhost:5001/#/experiments/1/runs/28438eb1ba68413ab95bd8e5f7b0864f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 174 at: http://localhost:5001/#/experiments/1/runs/02abb5a485d947c584542c363b9157a4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 175 at: http://localhost:5001/#/experiments/1/runs/2fbb0c28aaee4ea8ac43202b285b66cf
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 176 at: http://localhost:5001/#/experiments/1/runs/030fc5dc716e46459ca681dadb3ec4b3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 177 at: http://localhost:5001/#/experiments/1/runs/d776e7d96acc4ed3bdafd0299e3587ab
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 178 at: http://localhost:5001/#/experiments/1/runs/6ab799e778004b299bc4eaab38d77819
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 179 at: http://localhost:5001/#/experiments/1/runs/ebd7f365cb6f4f509aa80c4c8f429355
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 180 at: http://localhost:5001/#/experiments/1/runs/e37c9d02cc2647ff9d2b14b2a86d3af8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 181 at: http://localhost:5001/#/experiments/1/runs/51c7b91625bb49e29f4ab03e29a34045
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 182 at: http://localhost:5001/#/experiments/1/runs/8e80b05a06214fedbc28efb5671fd7f4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 183 at: http://localhost:5001/#/experiments/1/runs/f63175233faa4940850ba4d1c297fec3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 184 at: http://localhost:5001/#/experiments/1/runs/1306441874914783bdfa9cdcd425613f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 185 at: http://localhost:5001/#/experiments/1/runs/e1ff67ef49974259b1b2f8e2563198d9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 186 at: http://localhost:5001/#/experiments/1/runs/ff2a2b19889a42c790335d60d9f47773
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 187 at: http://localhost:5001/#/experiments/1/runs/81e48535a9aa4dde83801fe30c3b6435
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 188 at: http://localhost:5001/#/experiments/1/runs/e7b311cc31294621aa1acd9eb9291d50
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 189 at: http://localhost:5001/#/experiments/1/runs/ad7de44ee6644dbfafd72cfd22eb4aad
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 190 at: http://localhost:5001/#/experiments/1/runs/8e2d487d40804ae9876818e6223bfa58
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 191 at: http://localhost:5001/#/experiments/1/runs/bfe6692081cd4aa182a72a221939f129
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 192 at: http://localhost:5001/#/experiments/1/runs/0a98dd88897c4fa1b2993fd36a1858d0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 193 at: http://localhost:5001/#/experiments/1/runs/19db8444d3914264b61e68ab968955c5
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 194 at: http://localhost:5001/#/experiments/1/runs/607fe327f37843e19cae09a1e0b3b59d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 195 at: http://localhost:5001/#/experiments/1/runs/9a7dd0da5faa488e8cce0468e0ae7ace
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 196 at: http://localhost:5001/#/experiments/1/runs/c1dc631430e84560b0e1b48f0bf7738e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 197 at: http://localhost:5001/#/experiments/1/runs/86d9e5b4014b4193a806a3287d152453
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 198 at: http://localhost:5001/#/experiments/1/runs/bf2c4aa3e35846c7a20ff06015c8c669
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 199 at: http://localhost:5001/#/experiments/1/runs/beec8dbd60ae4215a8a6c70a6e250272
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 200 at: http://localhost:5001/#/experiments/1/runs/a16b6820e289481191c28ec38c4f8e21
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 201 at: http://localhost:5001/#/experiments/1/runs/08b0e3a518f14698ad16545c44242f2a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 202 at: http://localhost:5001/#/experiments/1/runs/4bf694086661411c9810c8b1a186f36d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 203 at: http://localhost:5001/#/experiments/1/runs/05c119189b3942e5b7b39d32cd5281e4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 204 at: http://localhost:5001/#/experiments/1/runs/554e26e57b2b4074a545c3091e4764f4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 205 at: http://localhost:5001/#/experiments/1/runs/74b615aad4fb43b1a192bb9bd6848217
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 206 at: http://localhost:5001/#/experiments/1/runs/7ad5a42444d04518b44af0184f707d12
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 207 at: http://localhost:5001/#/experiments/1/runs/c5970fc4d7384c9b963f71e0a6c5307f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 208 at: http://localhost:5001/#/experiments/1/runs/467070a2185945d4a82098bdcaf00f47
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 209 at: http://localhost:5001/#/experiments/1/runs/f5ce3e0a821f48baace4d53904bb3c83
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 210 at: http://localhost:5001/#/experiments/1/runs/6557143c7a8e4b76b1854acc1b871190
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 211 at: http://localhost:5001/#/experiments/1/runs/1cce3a37592941a1ab2f5ed9cc8c8131
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 212 at: http://localhost:5001/#/experiments/1/runs/3bc305e9a8e34a5eacfc534e6fb3292f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 213 at: http://localhost:5001/#/experiments/1/runs/0aeac3ae0f6d4f92a998e0620e503fb0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 214 at: http://localhost:5001/#/experiments/1/runs/c122994db9d64648b9a0fe8d935b5d5f
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 215 at: http://localhost:5001/#/experiments/1/runs/3b43a4bfc27f4962b40fae0c9d62ccb1
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 216 at: http://localhost:5001/#/experiments/1/runs/25b0335a104c4111aa8fb975634c169b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 217 at: http://localhost:5001/#/experiments/1/runs/0d99293d1e26411e802ce8d7ecc17546
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 218 at: http://localhost:5001/#/experiments/1/runs/10c078d6d18646d882050f772540a6fe
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 219 at: http://localhost:5001/#/experiments/1/runs/71bdb2d14b4744eab22289397550493a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 220 at: http://localhost:5001/#/experiments/1/runs/4e6e0a995d1c4c4d8dabe1b259b2fd3e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 221 at: http://localhost:5001/#/experiments/1/runs/c5945d0a1b484196a1ca3fdcf8cc41cc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 222 at: http://localhost:5001/#/experiments/1/runs/6aebc9c88e2442d7b47d420cf4cc5b1b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 223 at: http://localhost:5001/#/experiments/1/runs/2604937510be49f9839061b299b0a125
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 224 at: http://localhost:5001/#/experiments/1/runs/15c8694e6b67415b9f0510242df55ebc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 225 at: http://localhost:5001/#/experiments/1/runs/775ebd79be96425eaa4e204cde1a9330
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 226 at: http://localhost:5001/#/experiments/1/runs/57902cce0ade4742985a92c379321765
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 227 at: http://localhost:5001/#/experiments/1/runs/e285b86de2a648249f28afad4d0866da
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 228 at: http://localhost:5001/#/experiments/1/runs/8e96ba7fddb940a08492e65a27632927
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 229 at: http://localhost:5001/#/experiments/1/runs/c07cc8976bc249a5b2b46d1745f9a60d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 230 at: http://localhost:5001/#/experiments/1/runs/a5f941c39b06475494324d6e9af19228
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 231 at: http://localhost:5001/#/experiments/1/runs/bbed3d3a7c2243f79bd32c1d9e9b35ee
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 232 at: http://localhost:5001/#/experiments/1/runs/45f94566f6b04900b41f3b154a73f9c0
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 233 at: http://localhost:5001/#/experiments/1/runs/d3ef050246bb45a2a2261aae68a99682
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 234 at: http://localhost:5001/#/experiments/1/runs/f0f7dff2d4a94c17a9169ebaffea5f37
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 235 at: http://localhost:5001/#/experiments/1/runs/e52635149feb460a8bd1ecea1d6be4c8
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 236 at: http://localhost:5001/#/experiments/1/runs/6c78f3cd76644e2db730d30eb2c53315
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 237 at: http://localhost:5001/#/experiments/1/runs/bbb4a2ee29da4e07b7e37eb0ddf4fc0b
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 238 at: http://localhost:5001/#/experiments/1/runs/79d8dc5b7974483c8eff23d312dcb9b2
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 239 at: http://localhost:5001/#/experiments/1/runs/70b7fd9a548a42768e541284273c24f9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 240 at: http://localhost:5001/#/experiments/1/runs/dac62416b0344b5abf5b5fcf8200aed9
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 241 at: http://localhost:5001/#/experiments/1/runs/d8df29e2a62b4a60aac299ddeddf7dbd
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 242 at: http://localhost:5001/#/experiments/1/runs/a03fd6e0619f4df6a643fa0591800894
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 243 at: http://localhost:5001/#/experiments/1/runs/d71b8a4facac488ba26fb6ed403443b3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 244 at: http://localhost:5001/#/experiments/1/runs/2409ac7236c14f5aac6d1c42e5ffcc9e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 245 at: http://localhost:5001/#/experiments/1/runs/f17b0c7cdda14910b61d5de8568128dc
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 246 at: http://localhost:5001/#/experiments/1/runs/29f46277801a44e08aebdab93c834646
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 247 at: http://localhost:5001/#/experiments/1/runs/4e459bdf5a1e4917b633d61c5932edf3
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 248 at: http://localhost:5001/#/experiments/1/runs/c4fa90d1c2824c8ea15e573752302c9a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 🏃 View run Trial: 249 at: http://localhost:5001/#/experiments/1/runs/cda9be3ea89a40da962d3aa2ccf74179
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/07/13 04:18:04 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Successfully registered model 'heart_disease_model_dev'.
# 2025/07/13 04:18:04 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: heart_disease_model_dev, version 1
# 🏃 View run best_hyperparam_2025/07/13-04:17:37" at: http://localhost:5001/#/experiments/1/runs/b9c8198b92b340c4ac18031bc4b5bf57
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# Created version '1' of model 'heart_disease_model_dev'.

# %% [markdown]
# ## Testeando el modelo
#
# Una vez que el modelo fue entrenado, podemos levantarlo y testearlo de una forma agnóstica a donde está guardado.

# %%
loaded = mlflow.sklearn.load_model(model_uri)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import numpy as np
test_data = [-1.0431146438366603, 0.6689936080056726, 0.5955141571109206, 1.4218278518511829, -0.3955054753168235,
             -0.195684619877533, 1.445528359737701, -0.8782783888787548, -0.4354941703556927, -0.6313862911472252,
             1.0752906583803283, -0.0987729596649589, 0.957427107756338, 1.1071614388213236, -0.2991215208080594,
             -0.5494422557947561, -0.362142984170074, 4.690415759823429, -0.2253029545296664, 1.1980376111153852]
loaded.predict(np.array(test_data).reshape([1, -1]))
# Out:
# /Users/facundolucianna/Docencia/UBA/Aprendizaje de Maquina II/Repo/aprendizaje_maquina_II/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# ## Registramos el modelo
#
# Realizamos el registro del modelo en MLflow. En este registro se pone el modelo productivo que luego se usará para servir en formato on-line.

# %%
from mlflow import MlflowClient

client = MlflowClient()
name = "heart_disease_model_prod"
desc = "This classifier detects if a person has a heart disease"

# Creamos el modelo productivo
client.create_registered_model(name=name, description=desc)

# Guardamos como tag los hiper-parametros en la version del modelo
tags = model.get_params()
tags["model"] = type(model).__name__
tags["f1-score"] = f1_score

# Guardamos la version del modelo
result = client.create_model_version(
    name=name,
    source=model_uri,
    run_id=model_uri.split("/")[-3],
    tags=tags
)

# Y creamos como la version con el alias de champion para poder levantarlo en nuestro
# proceso de servicio del modelo on-line.
client.set_registered_model_alias(name, "champion", result.version)
# Out:
# 2025/07/13 04:18:14 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: heart_disease_model_prod, version 1
